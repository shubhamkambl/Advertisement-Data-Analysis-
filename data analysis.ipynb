# %%
import pandas as pd
data=pd.read_csv('http://www-bcf.usc.edu/~gareth/ISL/Advertising.csv')

# %%
data.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
data=pd.read_csv('http://www-bcf.usc.edu/~gareth/ISL/Advertising.csv')

# %%
data.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
import seaborn as sns
# %matplotlib inline
sns.pairplot(data,x_vars=['TV','radio','newspaper'],y_vars='sales')

# %%
import pandas as pd

# %%
data=pd.read_csv('http://www-bcf.usc.edu/~gareth/ISL/Advertising.csv')

# %%
data
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# 5             6    8.7   48.9       75.0    7.2
# 6             7   57.5   32.8       23.5   11.8
# 7             8  120.2   19.6       11.6   13.2
# 8             9    8.6    2.1        1.0    4.8
# 9            10  199.8    2.6       21.2   10.6
# 10           11   66.1    5.8       24.2    8.6
# 11           12  214.7   24.0        4.0   17.4
# 12           13   23.8   35.1       65.9    9.2
# 13           14   97.5    7.6        7.2    9.7
# 14           15  204.1   32.9       46.0   19.0
# 15           16  195.4   47.7       52.9   22.4
# 16           17   67.8   36.6      114.0   12.5
# 17           18  281.4   39.6       55.8   24.4
# 18           19   69.2   20.5       18.3   11.3
# ...

# %%
# %matplotlib inline
sns.pairplot(data,x_vars=['TV','radio','newspaper',],y_vars='sales')

# %%
data=pd.read_csv('http://www-bcf.usc.edu/~gareth/ISL/Advertising.csv',index_col=0)

# %%
data
# Out:
#         TV  radio  newspaper  sales
# 1    230.1   37.8       69.2   22.1
# 2     44.5   39.3       45.1   10.4
# 3     17.2   45.9       69.3    9.3
# 4    151.5   41.3       58.5   18.5
# 5    180.8   10.8       58.4   12.9
# 6      8.7   48.9       75.0    7.2
# 7     57.5   32.8       23.5   11.8
# 8    120.2   19.6       11.6   13.2
# 9      8.6    2.1        1.0    4.8
# 10   199.8    2.6       21.2   10.6
# 11    66.1    5.8       24.2    8.6
# 12   214.7   24.0        4.0   17.4
# 13    23.8   35.1       65.9    9.2
# 14    97.5    7.6        7.2    9.7
# 15   204.1   32.9       46.0   19.0
# 16   195.4   47.7       52.9   22.4
# 17    67.8   36.6      114.0   12.5
# 18   281.4   39.6       55.8   24.4
# 19    69.2   20.5       18.3   11.3
# 20   147.3   23.9       19.1   14.6
# 21   218.4   27.7       53.4   18.0
# 22   237.4    5.1       23.5   12.5
# 23    13.2   15.9       49.6    5.6
# 24   228.3   16.9       26.2   15.5
# 25    62.3   12.6       18.3    9.7
# ...

# %%
data.tail()
# Out:
#         TV  radio  newspaper  sales
# 196   38.2    3.7       13.8    7.6
# 197   94.2    4.9        8.1    9.7
# 198  177.0    9.3        6.4   12.8
# 199  283.6   42.0       66.2   25.5
# 200  232.1    8.6        8.7   13.4

# %%
import seaborn as sns
# %matplotlib inline
sns.pairplot(data,x_vars=['TV','radio','newspaper'],y_vars='sales')

# %%
import seaborn as sns
# %matplotlib inline
sns.pairplot(data,x_vars=['TV','radio','newspaper'],y_vars='sales',size=6)
# Out:
# C:\Anaconda\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
import seaborn as sns
# %matplotlib inline
sns.pairplot(data,x_vars=['TV','radio','newspaper'],y_vars='sales',aspect=.8
            )

# %%
import seaborn as sns
# %matplotlib inline
sns.pairplot(data,x_vars=['TV','radio','newspaper'],y_vars='sales',size=4,aspect=.8,kind='reg')
# Out:
# C:\Anaconda\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)
# C:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
feature_cols=['TV','radio','newspaper']
X=data[feature_cols]

# %%
y=data.sales

# %%
X
# Out:
#         TV  radio  newspaper
# 1    230.1   37.8       69.2
# 2     44.5   39.3       45.1
# 3     17.2   45.9       69.3
# 4    151.5   41.3       58.5
# 5    180.8   10.8       58.4
# 6      8.7   48.9       75.0
# 7     57.5   32.8       23.5
# 8    120.2   19.6       11.6
# 9      8.6    2.1        1.0
# 10   199.8    2.6       21.2
# 11    66.1    5.8       24.2
# 12   214.7   24.0        4.0
# 13    23.8   35.1       65.9
# 14    97.5    7.6        7.2
# 15   204.1   32.9       46.0
# 16   195.4   47.7       52.9
# 17    67.8   36.6      114.0
# 18   281.4   39.6       55.8
# 19    69.2   20.5       18.3
# 20   147.3   23.9       19.1
# 21   218.4   27.7       53.4
# 22   237.4    5.1       23.5
# 23    13.2   15.9       49.6
# 24   228.3   16.9       26.2
# 25    62.3   12.6       18.3
# 26   262.9    3.5       19.5
# 27   142.9   29.3       12.6
# 28   240.1   16.7       22.9
# 29   248.8   27.1       22.9
# 30    70.6   16.0       40.8
# ..     ...    ...        ...
# ...

# %%
type(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-74463a5214db> in <module>()
# ----> 1 type(y)
#
# NameError: name 'y' is not defined

# %%
from sklearn.cross_validation import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
linreg=LinearRegression()
linreg.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_pred=linreg.predict(X_test)

# %%
type(y_pred)
# Out:
# numpy.ndarray

# %%
from sklearn import metrics
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-34-df2c0d02b451> in <module>()
# ----> 1 from sklearn import matrices
#
# ImportError: cannot import name 'matrices' from 'sklearn' (C:\Anaconda\lib\site-packages\sklearn\__init__.py)

# %%
from sklearn import metrics

# %%
metrics.mean_absolute_error(y_test,y_pred)
# Out:
# 1.0668917082595213

# %%
metrics.mean_squared_error(y_test,y_pred)
# Out:
# 1.9730456202283384

# %%
import numpy as np

# %%
np.sqrt(metrics.mean_squared_error(y_test,y_pred))
# Out:
# 1.4046514230328955

# %%
feature_cols=['TV','radio']

# %%
type(feature_cols)
# Out:
# list

# %%
X=data[feature_cols]

# %%
X.head()
# Out:
#       TV  radio
# 1  230.1   37.8
# 2   44.5   39.3
# 3   17.2   45.9
# 4  151.5   41.3
# 5  180.8   10.8

# %%
y=data.sales

# %%
y.head()
# Out:
# 1    22.1
# 2    10.4
# 3     9.3
# 4    18.5
# 5    12.9
# Name: sales, dtype: float64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=1)

# %%
linreg.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_pred=linreg.predict(X_test)

# %%
np.sqrt(metrics.mean_squared_error(y_test,y_pred))
# Out:
# 1.3879034699382888

# %%
y_pred=linreg.predict(33.5)error
# Out:
#   File "<ipython-input-52-e01a1ce6844b>", line 1
#     y_pred=linreg.predict(33.5)error
#                                    ^
# SyntaxError: invalid syntax

# %%
X_test.TV
# Out:
# 59     210.8
# 41     202.5
# 35      95.7
# 103    280.2
# 185    253.8
# 199    283.6
# 96     163.3
# 5      180.8
# 30      70.6
# 169    215.4
# 172    164.5
# 19      69.2
# 12     214.7
# 90     109.8
# 111    225.8
# 119    125.7
# 160    131.7
# 36     290.7
# 137     25.6
# 60     210.7
# 52     100.4
# 17      67.8
# 45      25.1
# 95     107.4
# 32     112.9
# 163    188.4
# 39      43.1
# 29     248.8
# 194    166.8
# 28     240.1
# 48     239.9
# 166    234.5
# 195    149.7
# 178    170.2
# 177    248.4
# 98     184.9
# 175    222.4
# 74     129.4
# 70     216.8
# 173     19.6
# 109     13.1
# 108     90.4
# 190     18.7
# 15     204.1
# 57       7.3
# 20     147.3
# 115     78.2
# 40     228.0
# 186    205.0
# 125    229.5
# Name: TV, dtype: float64

# %%
type(X_test)
# Out:
# pandas.core.frame.DataFrame

# %%
y_pred=linreg.predict([[229.5,15.2]])

# %%
y_pred
# Out:
# array([16.37640431])

# %%
df=pd.DataFrame({"a":[1,2,3],"b":[4,5,6],"c":[7,8,9]},index=[10,11,12])

# %%
df=pd.DataFrame([[1,4,7],[2,5,8],[3,6,9]],index=[10,11,12],columns=["a","b","c"])

# %%
states ={'State' :['Gujarat', 'Tamil Nadu', ' Andhra', 'Karnataka',
'Kerala'], 'Population': [36, 44, 67,89,34],'Language' :['Gujarati',
'Tamil', 'Telugu', 'Kannada', 'Malayalam']}

# %%
State=pd.DataFrame(states)
State
# Out:
#         State  Population   Language
# 0     Gujarat          36   Gujarati
# 1  Tamil Nadu          44      Tamil
# 2      Andhra          67     Telugu
# 3   Karnataka          89    Kannada
# 4      Kerala          34  Malayalam

# %%
df=pd.DataFrame({"x1":['a','b','c'],"x2":[10,11,12]})
df
# Out:
#   x1  x2
# 0  a  10
# 1  b  11
# 2  c  12

# %%
df1=pd.DataFrame({"x1":['A','B','C'],"x3":["T","F","T"]})
df1
# Out:
#   x1 x3
# 0  A  T
# 1  B  F
# 2  C  T

# %%
pd.merge(df,df1,how='left',on='x1')
pd.merge(df,df1,how='right',on='x1')

pd.merge(df,df1,how='inner',on='x1')

pd.merge(df,df1,how='outer',on='x1')
# Out:
#   x1    x2   x3
# 0  a  10.0  NaN
# 1  b  11.0  NaN
# 2  c  12.0  NaN
# 3  A   NaN    T
# 4  B   NaN    F
# 5  C   NaN    T

# %%
import pandas as pd
data = pd.DataFrame({'group': ['a', 'a', 'a', 'b','b', 'b', 'c', 'c','c'],
'ounces': [4, 3, 12, 6, 7.5, 8, 3, 5, 6]})
data

data.describe()
# Out:
#           ounces
# count   9.000000
# mean    6.055556
# std     2.855307
# min     3.000000
# 25%     4.000000
# 50%     6.000000
# 75%     7.500000
# max    12.000000

# %%
feature_cols=['TV']

# %%
type=[feature_cols]

# %%
X.head()
# Out:
#       TV  radio
# 1  230.1   37.8
# 2   44.5   39.3
# 3   17.2   45.9
# 4  151.5   41.3
# 5  180.8   10.8

# %%
feat_cols=['TV']

# %%
type=[feat_cols]

# %%
X.head
# Out:
# <bound method NDFrame.head of         TV  radio
# 1    230.1   37.8
# 2     44.5   39.3
# 3     17.2   45.9
# 4    151.5   41.3
# 5    180.8   10.8
# 6      8.7   48.9
# 7     57.5   32.8
# 8    120.2   19.6
# 9      8.6    2.1
# 10   199.8    2.6
# 11    66.1    5.8
# 12   214.7   24.0
# 13    23.8   35.1
# 14    97.5    7.6
# 15   204.1   32.9
# 16   195.4   47.7
# 17    67.8   36.6
# 18   281.4   39.6
# 19    69.2   20.5
# 20   147.3   23.9
# 21   218.4   27.7
# 22   237.4    5.1
# 23    13.2   15.9
# 24   228.3   16.9
# 25    62.3   12.6
# 26   262.9    3.5
# 27   142.9   29.3
# 28   240.1   16.7
# 29   248.8   27.1
# 30    70.6   16.0
# ..     ...    ...
# 171   50.0   11.6
# 172  164.5   20.9
# 173   19.6   20.1
# 174  168.4    7.1
# 175  222.4    3.4
# 176  276.9   48.9
# 177  248.4   30.2
# 178  170.2    7.8
# 179  276.7    2.3
# 180  165.6   10.0
# 181  156.6    2.6
# 182  218.5    5.4
# 183   56.2    5.7
# 184  287.6   43.0
# 185  253.8   21.3
# 186  205.0   45.1
# ...

# %%
X.head()
# Out:
#       TV  radio
# 1  230.1   37.8
# 2   44.5   39.3
# 3   17.2   45.9
# 4  151.5   41.3
# 5  180.8   10.8

# %%
import pandas as pd

# %%
pd.read_csv('http://bit.ly/uforeports')
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# 5               Valley City             NaN           DISK    ND
# 6               Crater Lake             NaN         CIRCLE    CA
# 7                      Alma             NaN           DISK    MI
# 8                   Eklutna             NaN          CIGAR    AK
# 9                   Hubbard             NaN       CYLINDER    OR
# 10                  Fontana             NaN          LIGHT    CA
# 11                 Waterloo             NaN       FIREBALL    AL
# 12                   Belton             RED         SPHERE    SC
# ...

# %%
pd.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-76-ae60287777ef> in <module>()
# ----> 1 pd.head()
#
# AttributeError: module 'pandas' has no attribute 'head'

# %%
X.head()
# Out:
#       TV  radio
# 1  230.1   37.8
# 2   44.5   39.3
# 3   17.2   45.9
# 4  151.5   41.3
# 5  180.8   10.8

# %%
ufo=pd.read_csv('http://bit.ly/uforeports')

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.tail()
# Out:
#               City Colors Reported Shape Reported State              Time
# 18236   Grant Park             NaN       TRIANGLE    IL  12/31/2000 23:00
# 18237  Spirit Lake             NaN           DISK    IA  12/31/2000 23:00
# 18238  Eagle River             NaN            NaN    WI  12/31/2000 23:45
# 18239  Eagle River             RED          LIGHT    WI  12/31/2000 23:45
# 18240         Ybor             NaN           OVAL    FL  12/31/2000 23:59

# %%
print(data)
# Out:
#   group  ounces
# 0     a     4.0
# 1     a     3.0
# 2     a    12.0
# 3     b     6.0
# 4     b     7.5
# 5     b     8.0
# 6     c     3.0
# 7     c     5.0
# 8     c     6.0

# %%
ufo
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# 5               Valley City             NaN           DISK    ND
# 6               Crater Lake             NaN         CIRCLE    CA
# 7                      Alma             NaN           DISK    MI
# 8                   Eklutna             NaN          CIGAR    AK
# 9                   Hubbard             NaN       CYLINDER    OR
# 10                  Fontana             NaN          LIGHT    CA
# 11                 Waterloo             NaN       FIREBALL    AL
# 12                   Belton             RED         SPHERE    SC
# ...

# %%
ufo.mid()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-83-ce4708e722cb> in <module>()
# ----> 1 ufo.mid()
#
# C:\Anaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'mid'

# %%
ufo.shape
# Out:
# (18241, 5)

# %%
ufo.City()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-86-fe4896509fce> in <module>()
# ----> 1 ufo.City()
#
# TypeError: 'Series' object is not callable

# %%
ufo.City
# Out:
# 0                      Ithaca
# 1                 Willingboro
# 2                     Holyoke
# 3                     Abilene
# 4        New York Worlds Fair
# 5                 Valley City
# 6                 Crater Lake
# 7                        Alma
# 8                     Eklutna
# 9                     Hubbard
# 10                    Fontana
# 11                   Waterloo
# 12                     Belton
# 13                     Keokuk
# 14                  Ludington
# 15                Forest Home
# 16                Los Angeles
# 17                  Hapeville
# 18                     Oneida
# 19                 Bering Sea
# 20                   Nebraska
# 21                        NaN
# 22                        NaN
# 23                  Owensboro
# 24                 Wilderness
# 25                  San Diego
# 26                 Wilderness
# 27                     Clovis
# 28                 Los Alamos
# 29               Ft. Duschene
#                  ...
# ...

# %%
ufo['Colors Reported']
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          RED
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          RED
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28          NaN
# 29          NaN
#           ...
# 18211       NaN
# 18212       NaN
# 18213     GREEN
# 18214       NaN
# 18215       NaN
# 18216    ORANGE
# 18217       NaN
# 18218       NaN
# 18219       NaN
# 18220      BLUE
# 18221       NaN
# 18222       NaN
# 18223       NaN
# 18224       NaN
# 18225       NaN
# 18226       NaN
# 18227       NaN
# 18228       NaN
# 18229       NaN
# 18230       NaN
# 18231       NaN
# 18232       NaN
# 18233       RED
# 18234       NaN
# ...

# %%
ufo['Colors Reported'].shape
# Out:
# (18241,)

# %%
len(ufo)
# Out:
# 18241

# %%
ufo.rename(columns={'Colors Reported':'Colors Observed'})
# Out:
#                        City Colors Observed Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# 5               Valley City             NaN           DISK    ND
# 6               Crater Lake             NaN         CIRCLE    CA
# 7                      Alma             NaN           DISK    MI
# 8                   Eklutna             NaN          CIGAR    AK
# 9                   Hubbard             NaN       CYLINDER    OR
# 10                  Fontana             NaN          LIGHT    CA
# 11                 Waterloo             NaN       FIREBALL    AL
# 12                   Belton             RED         SPHERE    SC
# ...

# %%
ufo.rename(columns={'City_Reported':'Shahar_Reported','Shape Reported':'Akar_Reported'},inplace=True)

# %%
ufo.head()
# Out:
#                  Shahar Colors Reported Akar_Reported State             Time
# 0                Ithaca             NaN      TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN         OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN          OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN          DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN         LIGHT    NY  4/18/1933 19:00

# %%
ufo.rename(columns={'Shahar':'pimpalkhuta'})
# Out:
#                 pimpalkhuta Colors Reported Akar_Reported State  \
# 0                    Ithaca             NaN      TRIANGLE    NY
# 1               Willingboro             NaN         OTHER    NJ
# 2                   Holyoke             NaN          OVAL    CO
# 3                   Abilene             NaN          DISK    KS
# 4      New York Worlds Fair             NaN         LIGHT    NY
# 5               Valley City             NaN          DISK    ND
# 6               Crater Lake             NaN        CIRCLE    CA
# 7                      Alma             NaN          DISK    MI
# 8                   Eklutna             NaN         CIGAR    AK
# 9                   Hubbard             NaN      CYLINDER    OR
# 10                  Fontana             NaN         LIGHT    CA
# 11                 Waterloo             NaN      FIREBALL    AL
# 12                   Belton             RED        SPHERE    SC
# 13                   Keokuk             NaN          OVAL    IA
# ...

# %%
ufo.rename(columns={'pimpalkhuta':50})
# Out:
#                      Shahar Colors Reported Akar_Reported State  \
# 0                    Ithaca             NaN      TRIANGLE    NY
# 1               Willingboro             NaN         OTHER    NJ
# 2                   Holyoke             NaN          OVAL    CO
# 3                   Abilene             NaN          DISK    KS
# 4      New York Worlds Fair             NaN         LIGHT    NY
# 5               Valley City             NaN          DISK    ND
# 6               Crater Lake             NaN        CIRCLE    CA
# 7                      Alma             NaN          DISK    MI
# 8                   Eklutna             NaN         CIGAR    AK
# 9                   Hubbard             NaN      CYLINDER    OR
# 10                  Fontana             NaN         LIGHT    CA
# 11                 Waterloo             NaN      FIREBALL    AL
# 12                   Belton             RED        SPHERE    SC
# 13                   Keokuk             NaN          OVAL    IA
# ...

# %%
ufo_cols=['City','Colors_Reported','Shape_Reported']
ufo.colomns=ufo_cols
ufo.head()
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#                  Shahar Colors Reported Akar_Reported State             Time
# 0                Ithaca             NaN      TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN         OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN          OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN          DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN         LIGHT    NY  4/18/1933 19:00

# %%
ufo_cols=['शाहर', 'रंग', 'अंक', 'राज्य', 'सामय']
ufo.columns=ufo_cols
ufo.head()
# Out:
#                    शाहर  रंग       अंक राज्य             सामय
# 0                Ithaca  NaN  TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro  NaN     OTHER    NJ  6/30/1930 20:00
# 2               Holyoke  NaN      OVAL    CO  2/15/1931 14:00
# 3               Abilene  NaN      DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair  NaN     LIGHT    NY  4/18/1933 19:00

# %%
ufo.drop('रंग',axis=1,inplace=True)

# %%
ufo.drop([0,1],axis=0,inplace=True)

# %%
ufo.head()
# Out:
#                    शाहर     अंक राज्य             सामय
# 2               Holyoke    OVAL    CO  2/15/1931 14:00
# 3               Abilene    DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair   LIGHT    NY  4/18/1933 19:00
# 5           Valley City    DISK    ND  9/15/1934 15:30
# 6           Crater Lake  CIRCLE    CA   6/15/1935 0:00

# %%
movies=pd.read_csv('http://bit.ly/imdbratings')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2e7103439e40> in <module>()
# ----> 1 movies=pd.read_csv('http://bit.ly/imdbratings')
#
# NameError: name 'pd' is not defined

# %%
movies.import pandas as pd

# %%
movies=pd.read_csv('http://bit.ly/imdbratings')

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-09651a55b94e> in <module>()
# ----> 1 movies.shape()
#
# TypeError: 'tuple' object is not callable

# %%
movies=pd.read_csv('http://bit.ly/imdbrating')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-6-d64952fded59> in <module>()
# ----> 1 movies=pd.read_csv('http://bit.ly/imdbrating')
#
# C:\Anaconda\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# ...

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.title
# Out:
# 0                               The Shawshank Redemption
# 1                                          The Godfather
# 2                                 The Godfather: Part II
# 3                                        The Dark Knight
# 4                                           Pulp Fiction
# 5                                           12 Angry Men
# 6                         The Good, the Bad and the Ugly
# 7          The Lord of the Rings: The Return of the King
# 8                                       Schindler's List
# 9                                             Fight Club
# 10     The Lord of the Rings: The Fellowship of the Ring
# 11                                             Inception
# 12        Star Wars: Episode V - The Empire Strikes Back
# 13                                          Forrest Gump
# 14                 The Lord of the Rings: The Two Towers
# 15                                          Interstellar
# ...

# %%
movies.title.sort_values()
# Out:
# 542                   (500) Days of Summer
# 5                             12 Angry Men
# 201                       12 Years a Slave
# 698                              127 Hours
# 110                  2001: A Space Odyssey
# 910                                   2046
# 596                               21 Grams
# 624                              25th Hour
# 708                       28 Days Later...
# 60                                3 Idiots
# 225                                 3-Iron
# 570                                    300
# 555                           3:10 to Yuma
# 427           4 Months, 3 Weeks and 2 Days
# 824                                     42
# 597                                  50/50
# 203                                  8 1/2
# 170                       A Beautiful Mind
# 941                       A Bridge Too Far
# 571                           A Bronx Tale
# 266                      A Christmas Story
# 86                      A Clockwork Orange
# ...

# %%
movies.title.sort_values(ascending=True)
# Out:
# 542                   (500) Days of Summer
# 5                             12 Angry Men
# 201                       12 Years a Slave
# 698                              127 Hours
# 110                  2001: A Space Odyssey
# 910                                   2046
# 596                               21 Grams
# 624                              25th Hour
# 708                       28 Days Later...
# 60                                3 Idiots
# 225                                 3-Iron
# 570                                    300
# 555                           3:10 to Yuma
# 427           4 Months, 3 Weeks and 2 Days
# 824                                     42
# 597                                  50/50
# 203                                  8 1/2
# 170                       A Beautiful Mind
# 941                       A Bridge Too Far
# 571                           A Bronx Tale
# 266                      A Christmas Story
# 86                      A Clockwork Orange
# ...

# %%
movies.shape
# Out:
# (979, 6)

# %%
type(movies.title.sort_values(ascending=True))
# Out:
# pandas.core.series.Series

# %% [markdown]
# movies.actors_list.sort_values()

# %%
movies.actors_list.sort_values()
# Out:
# 464    [u"Brian O'Halloran", u'Jeff Anderson', u'Mari...
# 928    [u"Brian O'Halloran", u'Jeff Anderson', u'Rosa...
# 294    [u"Paige O'Hara", u'Robby Benson', u'Richard W...
# 85     [u"Peter O'Toole", u'Alec Guinness', u'Anthony...
# 245    [u"Ryan O'Neal", u'Marisa Berenson', u'Patrick...
# 142    [u'Aamir Khan', u'Gracy Singh', u'Rachel Shell...
# 60           [u'Aamir Khan', u'Madhavan', u'Mona Singh']
# 109    [u'Aamir Khan', u'Saif Ali Khan', u'Akshaye Kh...
# 72       [u'Aamir Khan', u'Soha Ali Khan', u'Siddharth']
# 714    [u'Aaron Eckhart', u'Cameron Bright', u'Maria ...
# 598    [u'Aaron Taylor-Johnson', u'Nicolas Cage', u'C...
# 831    [u'Adam Sandler', u'Don Cheadle', u'Jada Pinke...
# 656    [u'Adriana Caselotti', u'Harry Stockwell', u'L...
# 592    [u'Adrien Brody', u'Christina Hendricks', u'Ma...
# 42     [u'Adrien Brody', u'Thomas Kretschmann', u'Fra...
# 799    [u'Aksel Hennie', u'Synn\xf8ve Macody Lund', u...
# ...

# %%
movies.sort_values('content_rating','duration')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-3da62223561c> in <module>()
# ----> 1 movies.sort_values('content_rating','duration')
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4395                     kind='quicksort', na_position='last'):
#    4396         inplace = validate_bool_kwarg(inplace, 'inplace')
# -> 4397         axis = self._get_axis_number(axis)
#    4398         stacklevel = 2  # Number of stack levels from df.sort_values
#    4399
#
# C:\Anaconda\lib\site-packages\pandas\core\generic.py in _get_axis_number(self, axis)
#     373                 pass
#     374         raise ValueError('No axis named {0} for object type {1}'
# --> 375                          .format(axis, type(self)))
#     376
#     377     def _get_axis_name(self, axis):
#
# ...

# %%
movies.sort_values(['contetnt_rating','duration'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-9a8c024165a5> in <module>()
# ----> 1 movies.sort_values(['contetnt_rating','duration'])
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4409             for x in by:
#    4410                 k = self._get_label_or_level_values(x, axis=axis,
# -> 4411                                                     stacklevel=stacklevel)
#    4412                 keys.append(k)
#    4413             indexer = lexsort_indexer(keys, orders=ascending,
#
# C:\Anaconda\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis, stacklevel)
#    1380             values = self.axes[axis].get_level_values(key)._values
#    1381         else:
# -> 1382             raise KeyError(key)
#    1383
# ...

# %%
movies.sort_values(['content_rating','duration'])
# Out:
#      star_rating                               title content_rating  \
# 713          7.6                     The Jungle Book       APPROVED
# 513          7.8      Invasion of the Body Snatchers       APPROVED
# 272          8.1                         The Killing       APPROVED
# 703          7.6                             Dracula       APPROVED
# 612          7.7                  A Hard Day's Night       APPROVED
# 58           8.5                      Paths of Glory       APPROVED
# 210          8.1                               Laura       APPROVED
# 656          7.7     Snow White and the Seven Dwarfs       APPROVED
# 844          7.5                           Pinocchio       APPROVED
# 233          8.1             The Night of the Hunter       APPROVED
# 287          8.1                     His Girl Friday       APPROVED
# 484          7.8       The Day the Earth Stood Still       APPROVED
# 451          7.9              Miracle on 34th Street       APPROVED
# ...

# %%
movies.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-09651a55b94e> in <module>()
# ----> 1 movies.shape()
#
# TypeError: 'tuple' object is not callable

# %%
movies.shape
# Out:
# (979, 6)

# %%
booleans=[]
for length in movies.duration:
    if length>=200:
        boolean.append[True]
    else:
        boolean.append[False]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-112d7b46900a> in <module>()
#       4         boolean.append[True]
#       5     else:
# ----> 6         boolean.append[False]
#
# NameError: name 'boolean' is not defined

# %%
booleans=[]

# %%
for length in movies.duration:
    if length>=200:
        boolean.append[True]
    else:
        boolean.append[False]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-0a827d31c565> in <module>()
#       3         boolean.append[True]
#       4     else:
# ----> 5         boolean.append[False]
#
# NameError: name 'boolean' is not defined

# %%
for length in movies.duration:
    if length>=200:
        booleans.append[True]
    else:
        booleans.append[False]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-df211f3dbae6> in <module>()
#       3         booleans.append[True]
#       4     else:
# ----> 5         booleans.append[False]
#       6
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
booleans=[]
for length in movies.duration:
    if length>=200:
        booleans.append(True)
    else:
        booleans.append(False)

# %%
booleans[0:10]
# Out:
# [False, False, True, False, False, False, False, True, False, False]

# %%
type(booleans)
movies[booleans]
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 2                R      Crime       200
# 7            PG-13  Adventure       201
# ...

# %%
is_long=pd.Series(booleans)

# %%
type(is_long)
# Out:
# pandas.core.series.Series

# %%
is_long
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
# 5      False
# 6      False
# 7       True
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17      True
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 949    False
# 950    False
# 951    False
# 952    False
# 953    False
# 954    False
# 955    False
# 956    False
# 957    False
# 958    False
# 959    False
# 960    False
# 961    False
# 962    False
# 963    False
# 964    False
# 965    False
# 966    False
# 967    False
# 968    False
# 969    False
# 970    False
# 971    False
# 972    False
# 973    False
# 974    False
# 975    False
# 976    False
# 977    False
# 978    False
# Length: 979, dtype: bool

# %%
movies[is_long]
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 2                R      Crime       200
# 7            PG-13  Adventure       201
# ...

# %%
is_long=movies.duration>=180

# %%
is_long.head
# Out:
# <bound method NDFrame.head of 0      False
# 1      False
# 2       True
# 3      False
# 4      False
# 5      False
# 6      False
# 7       True
# 8       True
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17      True
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 949    False
# 950    False
# 951    False
# 952    False
# 953    False
# 954    False
# 955    False
# 956    False
# 957    False
# 958    False
# 959    False
# 960    False
# 961    False
# 962    False
# 963    False
# 964    False
# 965    False
# 966    False
# 967    False
# 968    False
# 969    False
# 970    False
# 971    False
# 972    False
# 973    False
# 974    False
# 975    False
# 976    False
# 977    False
# 978    False
# Name: duration, Length: 979, dtype: bool>

# %%
movies[movies.duration>=175]
# Out:
#      star_rating                                              title  \
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 14           8.8              The Lord of the Rings: The Two Towers
# 17           8.7                                      Seven Samurai
# 26           8.6                       Once Upon a Time in the West
# 40           8.5                                     The Green Mile
# 78           8.4                        Once Upon a Time in America
# 82           8.4                                         Braveheart
# 85           8.4                                 Lawrence of Arabia
# 89           8.4                                             Swades
# ...

# %%
#filtering

# %%
movies[movies.duration>=175].genre
# Out:
# 1          Crime
# 2          Crime
# 7      Adventure
# 8      Biography
# 10     Adventure
# 14     Adventure
# 17         Drama
# 26       Western
# 40         Crime
# 78         Crime
# 82        Action
# 85     Adventure
# 89         Drama
# 93        Comedy
# 109       Comedy
# 132        Drama
# 142    Adventure
# 143    Biography
# 156    Biography
# 157        Drama
# 166        Drama
# 184        Drama
# 204    Adventure
# 220    Biography
# 245    Adventure
# 300        Crime
# 316        Drama
# 318        Drama
# 335        Drama
# 339    Adventure
# 361        Drama
# 385       Action
# 424    Adventure
# 445    Adventure
# 456        Drama
# 476        Drama
# 534       Action
# 611       Comedy
# 620        Drama
# 630    Biography
# 671       Action
# 767       Action
# 941        Drama
# Name: genre, dtype: object

# %%
movies[movies.duration>=175].title
# Out:
# 1                                          The Godfather
# 2                                 The Godfather: Part II
# 7          The Lord of the Rings: The Return of the King
# 8                                       Schindler's List
# 10     The Lord of the Rings: The Fellowship of the Ring
# 14                 The Lord of the Rings: The Two Towers
# 17                                         Seven Samurai
# 26                          Once Upon a Time in the West
# 40                                        The Green Mile
# 78                           Once Upon a Time in America
# 82                                            Braveheart
# 85                                    Lawrence of Arabia
# 89                                                Swades
# 93                           Dilwale Dulhania Le Jayenge
# 109                                       Dil Chahta Hai
# 132                                Judgment at Nuremberg
# ...

# %%
movies[movies.duration>=175]['title']
# Out:
# 1                                          The Godfather
# 2                                 The Godfather: Part II
# 7          The Lord of the Rings: The Return of the King
# 8                                       Schindler's List
# 10     The Lord of the Rings: The Fellowship of the Ring
# 14                 The Lord of the Rings: The Two Towers
# 17                                         Seven Samurai
# 26                          Once Upon a Time in the West
# 40                                        The Green Mile
# 78                           Once Upon a Time in America
# 82                                            Braveheart
# 85                                    Lawrence of Arabia
# 89                                                Swades
# 93                           Dilwale Dulhania Le Jayenge
# 109                                       Dil Chahta Hai
# 132                                Judgment at Nuremberg
# ...

# %%
movies[(movies.duration>=180)&(movies.star_rating>=8.9)]
# Out:
#    star_rating                                          title content_rating  \
# 2          9.1                         The Godfather: Part II              R
# 7          8.9  The Lord of the Rings: The Return of the King          PG-13
# 8          8.9                               Schindler's List              R
#
#        genre  duration                                        actors_list
# 2      Crime       200  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 7  Adventure       201  [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 8  Biography       195  [u'Liam Neeson', u'Ralph Fiennes', u'Ben Kings...

# %%
movies.genre.isin(['Crime','Action','Drama'])
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
# 6      False
# 7      False
# 8      False
# 9       True
# 10     False
# 11      True
# 12      True
# 13      True
# 14     False
# 15     False
# 16      True
# 17      True
# 18     False
# 19      True
# 20      True
# 21      True
# 22      True
# 23      True
# 24      True
# 25     False
# 26     False
# 27      True
# 28      True
# 29     False
#        ...
# 949    False
# 950     True
# 951     True
# 952    False
# 953    False
# 954     True
# 955     True
# 956    False
# 957    False
# 958     True
# 959    False
# 960    False
# 961    False
# 962    False
# 963     True
# 964    False
# 965    False
# 966    False
# 967     True
# 968     True
# 969     True
# 970     True
# 971    False
# 972     True
# 973     True
# 974    False
# 975    False
# 976     True
# 977    False
# 978     True
# Name: genre, Length: 979, dtype: bool

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.tail()
# Out:
#      star_rating                                            title  \
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 974             PG     Comedy       116
# 975             PG  Adventure       118
# 976          PG-13     Action       138
# 977             PG     Horror       114
# 978              R      Crime       126
#
#                                            actors_list
# 974  [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...
# 975  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 977  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
# ...

# %%
movies[movies.genre.isin(['Crime','Drama','Action'])]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# 5            8.9                                     12 Angry Men
# 9            8.9                                       Fight Club
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 13           8.8                                     Forrest Gump
# 16           8.7                  One Flew Over the Cuckoo's Nest
# 17           8.7                                    Seven Samurai
# 19           8.7                                        Star Wars
# ...

# %%
orders=pd.read_table('http://bit.ly/chiporders')

# %%
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
orders
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 9            5         1                          Steak Burrito
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 13           7         1                           Chicken Bowl
# ...

# %%
orders=pd.read_table('http://bit.ly/chiporders')

# %%
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
orders.item_name.str.upper()
# Out:
# 0                CHIPS AND FRESH TOMATO SALSA
# 1                                        IZZE
# 2                            NANTUCKET NECTAR
# 3       CHIPS AND TOMATILLO-GREEN CHILI SALSA
# 4                                CHICKEN BOWL
# 5                                CHICKEN BOWL
# 6                               SIDE OF CHIPS
# 7                               STEAK BURRITO
# 8                            STEAK SOFT TACOS
# 9                               STEAK BURRITO
# 10                        CHIPS AND GUACAMOLE
# 11                       CHICKEN CRISPY TACOS
# 12                         CHICKEN SOFT TACOS
# 13                               CHICKEN BOWL
# 14                        CHIPS AND GUACAMOLE
# 15      CHIPS AND TOMATILLO-GREEN CHILI SALSA
# 16                            CHICKEN BURRITO
# 17                            CHICKEN BURRITO
# 18                                CANNED SODA
# 19                               CHICKEN BOWL
# ...

# %%
order.rename['order_id':'sr_no']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-cf5898c156c1> in <module>()
# ----> 1 order.rename['order_id':'sr_no']
#
# NameError: name 'order' is not defined

# %%
orders.item_name.str.contains('Chicken')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
# 5        True
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11       True
# 12       True
# 13       True
# 14      False
# 15      False
# 16       True
# 17       True
# 18      False
# 19       True
# 20      False
# 21      False
# 22      False
# 23       True
# 24      False
# 25      False
# 26       True
# 27      False
# 28      False
# 29       True
#         ...
# 4592    False
# 4593    False
# 4594    False
# 4595     True
# 4596    False
# 4597    False
# 4598    False
# 4599     True
# 4600    False
# 4601    False
# 4602    False
# 4603    False
# 4604     True
# 4605    False
# 4606    False
# 4607    False
# 4608    False
# 4609    False
# 4610    False
# 4611    False
# 4612    False
# 4613    False
# 4614    False
# 4615     True
# 4616    False
# 4617    False
# 4618    False
# 4619     True
# 4620     True
# 4621     True
# ...

# %%
orders[]
# Out:
#   File "<ipython-input-65-f6c75b1e912c>", line 1
#     orders[]
#            ^
# SyntaxError: invalid syntax

# %%
orders[orders.item_name.str.contains('Chicken')]
# Out:
#       order_id  quantity             item_name  \
# 4            2         2          Chicken Bowl
# 5            3         1          Chicken Bowl
# 11           6         1  Chicken Crispy Tacos
# 12           6         1    Chicken Soft Tacos
# 13           7         1          Chicken Bowl
# 16           8         1       Chicken Burrito
# 17           9         1       Chicken Burrito
# 19          10         1          Chicken Bowl
# 23          12         1       Chicken Burrito
# 26          13         1          Chicken Bowl
# 29          15         1       Chicken Burrito
# 35          18         1    Chicken Soft Tacos
# 36          18         1    Chicken Soft Tacos
# 42          20         1          Chicken Bowl
# 44          20         1    Chicken Salad Bowl
# 45          21         1       Chicken Burrito
# 52          24         1       Chicken Burrito
# 63          28         1       Chicken Burrito
# 68          30         1       Chicken Burrito
# ...

# %%
orders.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-b0b6cb4cf6cb> in <module>()
# ----> 1 orders.shape()
#
# TypeError: 'tuple' object is not callable

# %%
orders.choice_description.str.replace('[','')
# Out:
# 0                                                     NaN
# 1                                             Clementine]
# 2                                                  Apple]
# 3                                                     NaN
# 4       Tomatillo-Red Chili Salsa (Hot), Black Beans, ...
# 5       Fresh Tomato Salsa (Mild), Rice, Cheese, Sour ...
# 6                                                     NaN
# 7       Tomatillo Red Chili Salsa, Fajita Vegetables, ...
# 8       Tomatillo Green Chili Salsa, Pinto Beans, Chee...
# 9       Fresh Tomato Salsa, Rice, Black Beans, Pinto B...
# 10                                                    NaN
# 11      Roasted Chili Corn Salsa, Fajita Vegetables, R...
# 12      Roasted Chili Corn Salsa, Rice, Black Beans, C...
# 13      Fresh Tomato Salsa, Fajita Vegetables, Rice, C...
# 14                                                    NaN
# 15                                                    NaN
# ...

# %%
orders.choice_description.str.replace(']','')
# Out:
# 0                                                     NaN
# 1                                             [Clementine
# 2                                                  [Apple
# 3                                                     NaN
# 4       [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
# 5       [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...
# 6                                                     NaN
# 7       [Tomatillo Red Chili Salsa, [Fajita Vegetables...
# 8       [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...
# 9       [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...
# 10                                                    NaN
# 11      [Roasted Chili Corn Salsa, [Fajita Vegetables,...
# 12      [Roasted Chili Corn Salsa, [Rice, Black Beans,...
# 13      [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...
# 14                                                    NaN
# 15                                                    NaN
# ...

# %%
type(orders)
# Out:
# pandas.core.frame.DataFrame

# %%
drinks=pd.read_csv('http://bit.ly/drinksbycountry')

# %%
drinks
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 1                 Albania             89              132             54
# 2                 Algeria             25                0             14
# 3                 Andorra            245              138            312
# 4                  Angola            217               57             45
# 5       Antigua & Barbuda            102              128             45
# 6               Argentina            193               25            221
# 7                 Armenia             21              179             11
# 8               Australia            261               72            212
# 9                 Austria            279               75            191
# 10             Azerbaijan             21               46              5
# 11                Bahamas            122              176             51
# ...

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
drinks['beer_servings']=drinks.beer_servings.astype(float)

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# beer_serving                    float64
# dtype: object

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                   float64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# beer_serving                    float64
# dtype: object

# %%
drinks.head
# Out:
# <bound method NDFrame.head of                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan            0.0                0              0
# 1                 Albania           89.0              132             54
# 2                 Algeria           25.0                0             14
# 3                 Andorra          245.0              138            312
# 4                  Angola          217.0               57             45
# 5       Antigua & Barbuda          102.0              128             45
# 6               Argentina          193.0               25            221
# 7                 Armenia           21.0              179             11
# 8               Australia          261.0               72            212
# 9                 Austria          279.0               75            191
# 10             Azerbaijan           21.0               46              5
# ...

# %%
drinks.tail
# Out:
# <bound method NDFrame.tail of                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan            0.0                0              0
# 1                 Albania           89.0              132             54
# 2                 Algeria           25.0                0             14
# 3                 Andorra          245.0              138            312
# 4                  Angola          217.0               57             45
# 5       Antigua & Barbuda          102.0              128             45
# 6               Argentina          193.0               25            221
# 7                 Armenia           21.0              179             11
# 8               Australia          261.0               72            212
# 9                 Austria          279.0               75            191
# 10             Azerbaijan           21.0               46              5
# ...

# %%
drinks.head
# Out:
# <bound method NDFrame.head of                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan            0.0                0              0
# 1                 Albania           89.0              132             54
# 2                 Algeria           25.0                0             14
# 3                 Andorra          245.0              138            312
# 4                  Angola          217.0               57             45
# 5       Antigua & Barbuda          102.0              128             45
# 6               Argentina          193.0               25            221
# 7                 Armenia           21.0              179             11
# 8               Australia          261.0               72            212
# 9                 Austria          279.0               75            191
# 10             Azerbaijan           21.0               46              5
# ...

# %%
drinks.tail
# Out:
# <bound method NDFrame.tail of                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan            0.0                0              0
# 1                 Albania           89.0              132             54
# 2                 Algeria           25.0                0             14
# 3                 Andorra          245.0              138            312
# 4                  Angola          217.0               57             45
# 5       Antigua & Barbuda          102.0              128             45
# 6               Argentina          193.0               25            221
# 7                 Armenia           21.0              179             11
# 8               Australia          261.0               72            212
# 9                 Austria          279.0               75            191
# 10             Azerbaijan           21.0               46              5
# ...

# %%
orders.item_price.str.replace('$','')
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
# 5       10.98
# 6        1.69
# 7       11.75
# 8        9.25
# 9        9.25
# 10       4.45
# 11       8.75
# 12       8.75
# 13      11.25
# 14       4.45
# 15       2.39
# 16       8.49
# 17       8.49
# 18       2.18
# 19       8.75
# 20       4.45
# 21       8.99
# 22       3.39
# 23      10.98
# 24       3.39
# 25       2.39
# 26       8.49
# 27       8.99
# 28       1.09
# 29       8.49
#          ...
# 4592    11.75
# 4593    11.75
# 4594    11.75
# 4595     8.75
# 4596     4.45
# 4597     1.25
# 4598     1.50
# 4599     8.75
# 4600     4.45
# 4601     1.25
# 4602     9.25
# 4603     9.25
# 4604     8.75
# 4605     4.45
# 4606     1.25
# 4607    11.75
# 4608    11.25
# 4609     1.25
# 4610    11.75
# 4611    11.25
# 4612     9.25
# 4613     2.15
# 4614     1.50
# 4615     8.75
# 4616     4.45
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# ...

# %%
o=orders.item_price.str.replace('$','').astype(float)

# %%
orders.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
o=orders.item_price.str.replace('$','').astype(float)

# %%
orders.head
# Out:
# <bound method NDFrame.head of       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 9            5         1                          Steak Burrito
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# ...

# %%
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
orders.dtypes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-072c7ac1672d> in <module>()
# ----> 1 orders.dtypes()
#
# TypeError: 'Series' object is not callable

# %%
orders.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
drinks['beer_servings']=drinks.beer_servings.astype(float)

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                   float64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# beer_serving                    float64
# dtype: object

# %%
o.mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-99-3b631817e395> in <module>()
# ----> 1 o.mean()
#
# NameError: name 'o' is not defined

# %%
orders.mean()
# Out:
# order_id    927.254868
# quantity      1.075725
# dtype: float64

# %%
orders.max()
# Out:
# order_id                   1834
# quantity                     15
# item_name     Veggie Soft Tacos
# item_price               $9.39
# dtype: object

# %% [markdown]
# orders.min()

# %%
orders.sum()
# Out:
# order_id                                                4285772
# quantity                                                   4972
# item_name     Chips and Fresh Tomato SalsaIzzeNantucket Nect...
# item_price    $2.39 $3.39 $3.39 $2.39 $16.98 $10.98 $1.69 $1...
# dtype: object

# %%
omin()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-106-6f4e10348d0c> in <module>()
# ----> 1 o.min()
#
# AttributeError: 'float' object has no attribute 'min'

# %%
o.min()
# Out:
# 1.09

# %%
o.max()
# Out:
# 44.25

# %%
o.max()
# Out:
# 44.25

# %%
o.sum()
# Out:
# 34500.16

# %%
o.mean()
# Out:
# 7.464335785374397

# %%
orders[5:15]
# Out:
#     order_id  quantity             item_name  \
# 5          3         1          Chicken Bowl
# 6          3         1         Side of Chips
# 7          4         1         Steak Burrito
# 8          4         1      Steak Soft Tacos
# 9          5         1         Steak Burrito
# 10         5         1   Chips and Guacamole
# 11         6         1  Chicken Crispy Tacos
# 12         6         1    Chicken Soft Tacos
# 13         7         1          Chicken Bowl
# 14         7         1   Chips and Guacamole
#
#                                    choice_description item_price
# 5   [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 6                                                 NaN     $1.69
# 7   [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 8   [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25
# 9   [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25
# 10                                                NaN     $4.45
# ...

# %%
drinks[drinks.continent=='Africa'].beer_servings.mean
# Out:
# <bound method Series.mean of 2       25.0
# 4      217.0
# 18      34.0
# 22     173.0
# 26      25.0
# 27      88.0
# 28      37.0
# 29     144.0
# 31     147.0
# 33      17.0
# 34      15.0
# 38       1.0
# 39      76.0
# 47      32.0
# 49      15.0
# 53       6.0
# 55      92.0
# 56      18.0
# 58      20.0
# 62     347.0
# 63       8.0
# 66      31.0
# 70       9.0
# 71      28.0
# 88      58.0
# 95      82.0
# 96      19.0
# 97       0.0
# 100     26.0
# 101      8.0
# 104      5.0
# 107      0.0
# 108     98.0
# 114     12.0
# 115     47.0
# 117    376.0
# 123      3.0
# 124     42.0
# 142     43.0
# 148     56.0
# 150      9.0
# 152    157.0
# 153     25.0
# 158      0.0
# 159    225.0
# 162      8.0
# 164     90.0
# 172     36.0
# 175     51.0
# 179     45.0
# 183     36.0
# 191     32.0
# 192     64.0
# Name: beer_servings, dtype: float64>

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan            0.0                0              0
# 1      Albania           89.0              132             54
# 2      Algeria           25.0                0             14
# 3      Andorra          245.0              138            312
# 4       Angola          217.0               57             45
#
#    total_litres_of_pure_alcohol continent  beer_serving
# 0                           0.0      Asia           0.0
# 1                           4.9    Europe          89.0
# 2                           0.7    Africa          25.0
# 3                          12.4    Europe         245.0
# 4                           5.9    Africa         217.0

# %%
drinks[drinks.continent=='Asia'].beer_servings.mean
# Out:
# <bound method Series.mean of 0        0.0
# 12      42.0
# 13       0.0
# 19      23.0
# 24      31.0
# 30      57.0
# 36      79.0
# 46       0.0
# 77       9.0
# 78       5.0
# 79       0.0
# 80       9.0
# 82      63.0
# 85      77.0
# 86       6.0
# 87     124.0
# 90       0.0
# 91      31.0
# 92      62.0
# 94      20.0
# 102     13.0
# 103      0.0
# 112     77.0
# 116      5.0
# 119      5.0
# 127     22.0
# 128      0.0
# 134     71.0
# 137      1.0
# 138    140.0
# 141    247.0
# 149      0.0
# 154     60.0
# 161     16.0
# 167      5.0
# 168      2.0
# 169     99.0
# 171      1.0
# 176     51.0
# 177     19.0
# 181     16.0
# 186     25.0
# 189    111.0
# 190      6.0
# Name: beer_servings, dtype: float64>

# %%
99

# %% [markdown]
# k=drinks.beer_servings

# %%
k.mean
# Out:
# <bound method Series.mean of 0        0.0
# 1       89.0
# 2       25.0
# 3      245.0
# 4      217.0
# 5      102.0
# 6      193.0
# 7       21.0
# 8      261.0
# 9      279.0
# 10      21.0
# 11     122.0
# 12      42.0
# 13       0.0
# 14     143.0
# 15     142.0
# 16     295.0
# 17     263.0
# 18      34.0
# 19      23.0
# 20     167.0
# 21      76.0
# 22     173.0
# 23     245.0
# 24      31.0
# 25     231.0
# 26      25.0
# 27      88.0
# 28      37.0
# 29     144.0
#        ...
# 163    128.0
# 164     90.0
# 165    152.0
# 166    185.0
# 167      5.0
# 168      2.0
# 169     99.0
# 170    106.0
# 171      1.0
# 172     36.0
# 173     36.0
# 174    197.0
# 175     51.0
# 176     51.0
# 177     19.0
# 178      6.0
# 179     45.0
# 180    206.0
# 181     16.0
# 182    219.0
# 183     36.0
# 184    249.0
# 185    115.0
# 186     25.0
# 187     21.0
# 188    333.0
# 189    111.0
# 190      6.0
# 191     32.0
# 192     64.0
# Name: beer_servings, Length: 193, dtype: float64>

# %%
k.sum()
# Out:
# 20489.0

# %%
len(k)
# Out:
# 193

# %%
k.max()
# Out:
# 376.0

# %%
drinks[drinks.continent=='Asia'].beer_servings.max()
# Out:
# 247.0

# %%
drinks.groupby('country').beer_servings.max()
# Out:
# country
# Afghanistan               0.0
# Albania                  89.0
# Algeria                  25.0
# Andorra                 245.0
# Angola                  217.0
# Antigua & Barbuda       102.0
# Argentina               193.0
# Armenia                  21.0
# Australia               261.0
# Austria                 279.0
# Azerbaijan               21.0
# Bahamas                 122.0
# Bahrain                  42.0
# Bangladesh                0.0
# Barbados                143.0
# Belarus                 142.0
# Belgium                 295.0
# Belize                  263.0
# Benin                    34.0
# Bhutan                   23.0
# Bolivia                 167.0
# Bosnia-Herzegovina       76.0
# Botswana                173.0
# Brazil                  245.0
# Brunei                   31.0
# Bulgaria                231.0
# Burkina Faso             25.0
# Burundi                  88.0
# Cabo Verde              144.0
# Cambodia                 57.0
#                         ...
# ...

# %%
drinks.groupby('continent').beer_servings.agg(['count','min','max','mean'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-fc74597c48db> in <module>()
# ----> 1 drinks.groupby('continent').beer_servings.agg(['count','min','max','mean'])
#
# NameError: name 'drinks' is not defined

# %%
drinks.groupby('country').beer_servings.agg(['count','min','max','mean'])
# Out:
#                       count    min    max   mean
# country
# Afghanistan               1    0.0    0.0    0.0
# Albania                   1   89.0   89.0   89.0
# Algeria                   1   25.0   25.0   25.0
# Andorra                   1  245.0  245.0  245.0
# Angola                    1  217.0  217.0  217.0
# Antigua & Barbuda         1  102.0  102.0  102.0
# Argentina                 1  193.0  193.0  193.0
# Armenia                   1   21.0   21.0   21.0
# Australia                 1  261.0  261.0  261.0
# Austria                   1  279.0  279.0  279.0
# Azerbaijan                1   21.0   21.0   21.0
# Bahamas                   1  122.0  122.0  122.0
# Bahrain                   1   42.0   42.0   42.0
# Bangladesh                1    0.0    0.0    0.0
# Barbados                  1  143.0  143.0  143.0
# Belarus                   1  142.0  142.0  142.0
# Belgium                   1  295.0  295.0  295.0
# Belize                    1  263.0  263.0  263.0
# ...

# %%
drinks.groupby('country').beer_servings.agg(['count','min','max','mean'])
# Out:
#                       count    min    max   mean
# country
# Afghanistan               1    0.0    0.0    0.0
# Albania                   1   89.0   89.0   89.0
# Algeria                   1   25.0   25.0   25.0
# Andorra                   1  245.0  245.0  245.0
# Angola                    1  217.0  217.0  217.0
# Antigua & Barbuda         1  102.0  102.0  102.0
# Argentina                 1  193.0  193.0  193.0
# Armenia                   1   21.0   21.0   21.0
# Australia                 1  261.0  261.0  261.0
# Austria                   1  279.0  279.0  279.0
# Azerbaijan                1   21.0   21.0   21.0
# Bahamas                   1  122.0  122.0  122.0
# Bahrain                   1   42.0   42.0   42.0
# Bangladesh                1    0.0    0.0    0.0
# Barbados                  1  143.0  143.0  143.0
# Belarus                   1  142.0  142.0  142.0
# Belgium                   1  295.0  295.0  295.0
# Belize                    1  263.0  263.0  263.0
# ...

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan            0.0                0              0
# 1      Albania           89.0              132             54
# 2      Algeria           25.0                0             14
# 3      Andorra          245.0              138            312
# 4       Angola          217.0               57             45
#
#    total_litres_of_pure_alcohol continent  beer_serving
# 0                           0.0      Asia           0.0
# 1                           4.9    Europe          89.0
# 2                           0.7    Africa          25.0
# 3                          12.4    Europe         245.0
# 4                           5.9    Africa         217.0

# %%
drinks.groupby('continent').mean()
# Out:
#                beer_servings  spirit_servings  wine_servings  \
# continent
# Africa             61.471698        16.339623      16.264151
# Asia               37.045455        60.840909       9.068182
# Europe            193.777778       132.555556     142.222222
# North America     145.434783       165.739130      24.521739
# Oceania            89.687500        58.437500      35.625000
# South America     175.083333       114.750000      62.416667
#
#                total_litres_of_pure_alcohol  beer_serving
# continent
# Africa                             3.007547     61.471698
# Asia                               2.170455     37.045455
# Europe                             8.617778    193.777778
# North America                      5.995652    145.434783
# Oceania                            3.381250     89.687500
# South America                      6.308333    175.083333

# %%
# %matplotlib inline
drinks.groupby('continent').mean().plot(kind='bar')

# %%
# %matplotlib inline
drinks.groupby('continent').mean().plot(kind='bar')

# %%
drinks[drinks.continent=='Asia'].plot(kind='bar')

# %%
# Out:
#   File "<ipython-input-155-eeb5360088b8>", line 1
#     drinks.('country').beer_serving.max()
#            ^
# SyntaxError: invalid syntax

# %%
drinks.sort_values(['beer_servings'],ascending=False)
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 117             Namibia          376.0                3              1
# 45       Czech Republic          361.0              170            134
# 62                Gabon          347.0               98             59
# 65              Germany          346.0              117            175
# 98            Lithuania          343.0              244             56
# 135              Poland          343.0              215             56
# 188           Venezuela          333.0              100              3
# 81              Ireland          313.0              118            165
# 129               Palau          306.0               63             23
# 140             Romania          297.0              122            167
# 16              Belgium          295.0               84            212
# 130              Panama          285.0              104             18
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-4-6c6908107082> in <module>()
# ----> 1 h=pd.read_csv('http://www.gmail.com')
#
# C:\Anaconda\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# ...

# %%
drinks=pd.read_csv('http://bit.ly/drinksbycountry')

# %%
drinks.head
# Out:
# <bound method NDFrame.head of                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 1                 Albania             89              132             54
# 2                 Algeria             25                0             14
# 3                 Andorra            245              138            312
# 4                  Angola            217               57             45
# 5       Antigua & Barbuda            102              128             45
# 6               Argentina            193               25            221
# 7                 Armenia             21              179             11
# 8               Australia            261               72            212
# 9                 Austria            279               75            191
# 10             Azerbaijan             21               46              5
# ...

# %%
drinks.tail
# Out:
# <bound method NDFrame.tail of                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 1                 Albania             89              132             54
# 2                 Algeria             25                0             14
# 3                 Andorra            245              138            312
# 4                  Angola            217               57             45
# 5       Antigua & Barbuda            102              128             45
# 6               Argentina            193               25            221
# 7                 Armenia             21              179             11
# 8               Australia            261               72            212
# 9                 Austria            279               75            191
# 10             Azerbaijan             21               46              5
# ...

# %%
drinks
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 1                 Albania             89              132             54
# 2                 Algeria             25                0             14
# 3                 Andorra            245              138            312
# 4                  Angola            217               57             45
# 5       Antigua & Barbuda            102              128             45
# 6               Argentina            193               25            221
# 7                 Armenia             21              179             11
# 8               Australia            261               72            212
# 9                 Austria            279               75            191
# 10             Azerbaijan             21               46              5
# 11                Bahamas            122              176             51
# ...

# %%
drinks.sort_values(['beer_servings'],ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-ed6ae2763fce> in <module>()
# ----> 1 drinks.sort_values(['beer_servings'],ascending=False)
#
# NameError: name 'drinks' is not defined

# %%
import h2o

# %%
h2o.init(nthreads=-1)
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321..... not found.
# Attempting to start a local H2O server...
# ; Java HotSpot(TM) 64-Bit Server VM (build 25.181-b13, mixed mode)
#   Starting server from C:\Anaconda\lib\site-packages\h2o\backend\bin\h2o.jar
#   Ice root: C:\Users\Lenovo\AppData\Local\Temp\tmpkt9eawf3
#   JVM stdout: C:\Users\Lenovo\AppData\Local\Temp\tmpkt9eawf3\h2o_Lenovo_started_from_python.out
#   JVM stderr: C:\Users\Lenovo\AppData\Local\Temp\tmpkt9eawf3\h2o_Lenovo_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321... successful.
# --------------------------  -------------------------------
# H2O cluster uptime:         03 secs
# H2O cluster timezone:       Asia/Kolkata
# H2O data parsing timezone:  UTC
# H2O cluster version:        3.20.0.9
# H2O cluster version age:    10 days
# H2O cluster name:           H2O_from_python_Lenovo_wins2j
# ...

# %%
import h2o

# %%
import h2o

# %%
h2o.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bd4491091e43> in <module>()
# ----> 1 h2o.head()
#
# NameError: name 'h2o' is not defined

# %%
import pandas as pd

# %%
drinks=pd.read_csv('http://bit.ly/drinksbycountry')

# %%
m=drinks.beer_servings.max()

# %%
m=drinks.beer_servings.max()

# %%
m
# Out:
# 376

# %%
drinks.loc[drinks['beer_servings']==m]
# Out:
#      country  beer_servings  spirit_servings  wine_servings  \
# 117  Namibia            376                3              1
#
#      total_litres_of_pure_alcohol continent
# 117                           6.8    Africa

# %%
drinks.loc[drinks.beer_servings==m]
# Out:
#      country  beer_servings  spirit_servings  wine_servings  \
# 117  Namibia            376                3              1
#
#      total_litres_of_pure_alcohol continent
# 117                           6.8    Africa

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-72207a61b2f1> in <module>()
# ----> 1 datas=h2o.import_file(r"C:\Users\Lenovo\Desktop\dataset\winequality-white.csv")
#
# NameError: name 'h2o' is not defined

# %%
import h2o
h2o.init
# Out:
# <function h2o.h2o.init(url=None, ip=None, port=None, https=None, insecure=None, username=None, password=None, cookies=None, proxy=None, start_h2o=True, nthreads=-1, ice_root=None, enable_assertions=True, max_mem_size=None, min_mem_size=None, strict_version_check=None, ignore_config=False, extra_classpath=None, **kwargs)>

# %%
datas=h2o.import_file(r"C:\Users\Lenovo\Desktop\dataset\winequality-white.csv")
# Out:
# ---------------------------------------------------------------------------
# H2OConnectionError                        Traceback (most recent call last)
# <ipython-input-26-72207a61b2f1> in <module>()
# ----> 1 datas=h2o.import_file(r"C:\Users\Lenovo\Desktop\dataset\winequality-white.csv")
#
# C:\Anaconda\lib\site-packages\h2o\h2o.py in import_file(path, destination_frame, parse, header, sep, col_names, col_types, na_strings, pattern)
#     410         return lazy_import(path, pattern)
#     411     else:
# --> 412         return H2OFrame()._import_parse(path, pattern, destination_frame, header, sep, col_names, col_types, na_strings)
#     413
#     414
#
# C:\Anaconda\lib\site-packages\h2o\frame.py in _import_parse(self, path, pattern, destination_frame, header, separator, column_names, column_types, na_strings)
#     312         if H2OFrame.__LOCAL_EXPANSION_ON_SINGLE_IMPORT__ and is_type(path, str) and "://" not in path:  # fixme: delete those 2 lines, cf. PUBDEV-5717
# ...

# %%
import h2o

# %%
h2o.init(nthreads=-1)
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321. connected.
# --------------------------  -------------------------------
# H2O cluster uptime:         51 mins 07 secs
# H2O cluster timezone:       Asia/Kolkata
# H2O data parsing timezone:  UTC
# H2O cluster version:        3.20.0.9
# H2O cluster version age:    10 days
# H2O cluster name:           H2O_from_python_Lenovo_wins2j
# H2O cluster total nodes:    1
# H2O cluster free memory:    1.748 Gb
# H2O cluster total cores:    4
# H2O cluster allowed cores:  4
# H2O cluster status:         locked, healthy
# H2O connection url:         http://localhost:54321
# H2O connection proxy:
# H2O internal security:      False
# H2O API Extensions:         Algos, AutoML, Core V3, Core V4
# Python version:             3.7.0 final
# --------------------------  -------------------------------

# %%
datas=h2o.import_file(r"C:\Users\Lenovo\Desktop\dataset\winequality-white.csv")
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
df_h=H2OFrame(drinks)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-9b0e1ba875b2> in <module>()
# ----> 1 df_h=H2OFrame(drinks)
#
# NameError: name 'H2OFrame' is not defined

# %%
import h2o
h2o.init(nthreads=-1)
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321. connected.
# --------------------------  -------------------------------
# H2O cluster uptime:         56 mins 59 secs
# H2O cluster timezone:       Asia/Kolkata
# H2O data parsing timezone:  UTC
# H2O cluster version:        3.20.0.9
# H2O cluster version age:    10 days
# H2O cluster name:           H2O_from_python_Lenovo_wins2j
# H2O cluster total nodes:    1
# H2O cluster free memory:    1.748 Gb
# H2O cluster total cores:    4
# H2O cluster allowed cores:  4
# H2O cluster status:         locked, healthy
# H2O connection url:         http://localhost:54321
# H2O connection proxy:
# H2O internal security:      False
# H2O API Extensions:         Algos, AutoML, Core V3, Core V4
# Python version:             3.7.0 final
# --------------------------  -------------------------------

# %%
df=pd.read_csv('http://bit.ly/drinksbycountry')

# %%
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
import h2o

# %%
df_h=h2o.H2OFrame(df)
# Out:
# C:\Anaconda\lib\site-packages\h2o\utils\shared_utils.py:177: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   data = _handle_python_lists(python_obj.as_matrix().tolist(), -1)[1]
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df_h)
# Out:
# h2o.frame.H2OFrame

# %%
titanic=h2o.import_file(r'C:\Users\Lenovo\Desktop\dataset\titanic.csv')
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
titanic.head()
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  survived</th><th style="text-align: right;">  pclass</th><th>name                                               </th><th>sex   </th><th style="text-align: right;">  age</th><th style="text-align: right;">  sibsp</th><th style="text-align: right;">  parch</th><th style="text-align: right;">  ticket</th><th style="text-align: right;">   fare</th><th>cabin  </th><th>embarked  </th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">         0</td><td style="text-align: right;">       3</td><td>Braund, Mr. Owen Harris                            </td><td>male  </td><td style="text-align: right;">   22</td><td style="text-align: right;">      1</td><td style="text-align: right;">      0</td><td style="text-align: right;">     nan</td><td style="text-align: right;"> 7.25  </td><td>       </td><td>S         </td></tr>
# ...

# %%
titanic.head(6)
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  survived</th><th style="text-align: right;">  pclass</th><th>name                                               </th><th>sex   </th><th style="text-align: right;">  age</th><th style="text-align: right;">  sibsp</th><th style="text-align: right;">  parch</th><th style="text-align: right;">  ticket</th><th style="text-align: right;">   fare</th><th>cabin  </th><th>embarked  </th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">         0</td><td style="text-align: right;">       3</td><td>Braund, Mr. Owen Harris                            </td><td>male  </td><td style="text-align: right;">   22</td><td style="text-align: right;">      1</td><td style="text-align: right;">      0</td><td style="text-align: right;">     nan</td><td style="text-align: right;"> 7.25  </td><td>       </td><td>S         </td></tr>
# ...

# %%
titanic['survived'].summary()
# Out:
# <table>
# <thead>
# <tr><th>       </th><th>survived          </th></tr>
# </thead>
# <tbody>
# <tr><td>type   </td><td>int               </td></tr>
# <tr><td>mins   </td><td>0.0               </td></tr>
# <tr><td>mean   </td><td>0.3838383838383838</td></tr>
# <tr><td>maxs   </td><td>1.0               </td></tr>
# <tr><td>sigma  </td><td>0.4865924542648575</td></tr>
# <tr><td>zeros  </td><td>549               </td></tr>
# <tr><td>missing</td><td>0                 </td></tr>
# <tr><td>0      </td><td>0.0               </td></tr>
# <tr><td>1      </td><td>1.0               </td></tr>
# <tr><td>2      </td><td>1.0               </td></tr>
# <tr><td>3      </td><td>1.0               </td></tr>
# <tr><td>4      </td><td>0.0               </td></tr>
# <tr><td>5      </td><td>0.0               </td></tr>
# <tr><td>6      </td><td>0.0               </td></tr>
# <tr><td>7      </td><td>0.0               </td></tr>
# <tr><td>8      </td><td>1.0               </td></tr>
# ...

# %%
titanic['survived'].hist()
# Out:
# C:\Anaconda\lib\site-packages\matplotlib\__init__.py:1867: MatplotlibDeprecationWarning: The *left* kwarg to `bar` is deprecated use *x* instead. Support for *left* will be removed in Matplotlib 3.0
#   return func(ax, *args, **kwargs)

# %%
titanic['survived'].table()
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  survived</th><th style="text-align: right;">  Count</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">         0</td><td style="text-align: right;">    549</td></tr>
# <tr><td style="text-align: right;">         1</td><td style="text-align: right;">    342</td></tr>
# </tbody>
# </table>

# %%
titanic['age'].table()
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  age</th><th style="text-align: right;">  Counts</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;"> 0.42</td><td style="text-align: right;">       1</td></tr>
# <tr><td style="text-align: right;"> 0.67</td><td style="text-align: right;">       1</td></tr>
# <tr><td style="text-align: right;"> 0.75</td><td style="text-align: right;">       2</td></tr>
# <tr><td style="text-align: right;"> 0.83</td><td style="text-align: right;">       2</td></tr>
# <tr><td style="text-align: right;"> 0.92</td><td style="text-align: right;">       1</td></tr>
# <tr><td style="text-align: right;"> 1   </td><td style="text-align: right;">       7</td></tr>
# <tr><td style="text-align: right;"> 2   </td><td style="text-align: right;">      10</td></tr>
# <tr><td style="text-align: right;"> 3   </td><td style="text-align: right;">       6</td></tr>
# ...

# %%
titanic['survived'].summary()
# Out:
# <table>
# <thead>
# <tr><th>       </th><th>survived          </th></tr>
# </thead>
# <tbody>
# <tr><td>type   </td><td>int               </td></tr>
# <tr><td>mins   </td><td>0.0               </td></tr>
# <tr><td>mean   </td><td>0.3838383838383838</td></tr>
# <tr><td>maxs   </td><td>1.0               </td></tr>
# <tr><td>sigma  </td><td>0.4865924542648575</td></tr>
# <tr><td>zeros  </td><td>549               </td></tr>
# <tr><td>missing</td><td>0                 </td></tr>
# <tr><td>0      </td><td>0.0               </td></tr>
# <tr><td>1      </td><td>1.0               </td></tr>
# <tr><td>2      </td><td>1.0               </td></tr>
# <tr><td>3      </td><td>1.0               </td></tr>
# <tr><td>4      </td><td>0.0               </td></tr>
# <tr><td>5      </td><td>0.0               </td></tr>
# <tr><td>6      </td><td>0.0               </td></tr>
# <tr><td>7      </td><td>0.0               </td></tr>
# <tr><td>8      </td><td>1.0               </td></tr>
# ...

# %%
titanic['survived']=titanic['survived'].asfactor()

# %%
titanic['survived'].summary()
# Out:
# <table>
# <thead>
# <tr><th>       </th><th>survived  </th></tr>
# </thead>
# <tbody>
# <tr><td>type   </td><td>enum      </td></tr>
# <tr><td>mins   </td><td>          </td></tr>
# <tr><td>mean   </td><td>          </td></tr>
# <tr><td>maxs   </td><td>          </td></tr>
# <tr><td>sigma  </td><td>          </td></tr>
# <tr><td>zeros  </td><td>          </td></tr>
# <tr><td>missing</td><td>0         </td></tr>
# <tr><td>0      </td><td>0         </td></tr>
# <tr><td>1      </td><td>1         </td></tr>
# <tr><td>2      </td><td>1         </td></tr>
# <tr><td>3      </td><td>1         </td></tr>
# <tr><td>4      </td><td>0         </td></tr>
# <tr><td>5      </td><td>0         </td></tr>
# <tr><td>6      </td><td>0         </td></tr>
# <tr><td>7      </td><td>0         </td></tr>
# <tr><td>8      </td><td>1         </td></tr>
# <tr><td>9      </td><td>1         </td></tr>
# </tbody>
# </table>

# %%
titanic['pclass'].table()
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  pclass</th><th style="text-align: right;">  Count</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">       1</td><td style="text-align: right;">    216</td></tr>
# <tr><td style="text-align: right;">       2</td><td style="text-align: right;">    184</td></tr>
# <tr><td style="text-align: right;">       3</td><td style="text-align: right;">    491</td></tr>
# </tbody>
# </table>

# %%
titanic['pclass'].summary()
# Out:
# <table>
# <thead>
# <tr><th>       </th><th>pclass            </th></tr>
# </thead>
# <tbody>
# <tr><td>type   </td><td>int               </td></tr>
# <tr><td>mins   </td><td>1.0               </td></tr>
# <tr><td>mean   </td><td>2.3086419753086447</td></tr>
# <tr><td>maxs   </td><td>3.0               </td></tr>
# <tr><td>sigma  </td><td>0.8360712409770491</td></tr>
# <tr><td>zeros  </td><td>0                 </td></tr>
# <tr><td>missing</td><td>0                 </td></tr>
# <tr><td>0      </td><td>3.0               </td></tr>
# <tr><td>1      </td><td>1.0               </td></tr>
# <tr><td>2      </td><td>3.0               </td></tr>
# <tr><td>3      </td><td>1.0               </td></tr>
# <tr><td>4      </td><td>3.0               </td></tr>
# <tr><td>5      </td><td>3.0               </td></tr>
# <tr><td>6      </td><td>1.0               </td></tr>
# <tr><td>7      </td><td>3.0               </td></tr>
# <tr><td>8      </td><td>3.0               </td></tr>
# ...

# %%
titanic['pclass']=titanic['pclass'].asfactor()

# %%
titanic['pclass'].summary()
# Out:
# <table>
# <thead>
# <tr><th>       </th><th>pclass  </th></tr>
# </thead>
# <tbody>
# <tr><td>type   </td><td>enum    </td></tr>
# <tr><td>mins   </td><td>        </td></tr>
# <tr><td>mean   </td><td>        </td></tr>
# <tr><td>maxs   </td><td>        </td></tr>
# <tr><td>sigma  </td><td>        </td></tr>
# <tr><td>zeros  </td><td>        </td></tr>
# <tr><td>missing</td><td>0       </td></tr>
# <tr><td>0      </td><td>3       </td></tr>
# <tr><td>1      </td><td>1       </td></tr>
# <tr><td>2      </td><td>3       </td></tr>
# <tr><td>3      </td><td>1       </td></tr>
# <tr><td>4      </td><td>3       </td></tr>
# <tr><td>5      </td><td>3       </td></tr>
# <tr><td>6      </td><td>1       </td></tr>
# <tr><td>7      </td><td>3       </td></tr>
# <tr><td>8      </td><td>3       </td></tr>
# <tr><td>9      </td><td>2       </td></tr>
# </tbody>
# </table>

# %%
titanic['pclass'].hist()
# Out:
# ---------------------------------------------------------------------------
# H2OResponseError                          Traceback (most recent call last)
# <ipython-input-68-fc8301682e11> in <module>()
# ----> 1 titanic['pclass'].hist()
#
# C:\Anaconda\lib\site-packages\h2o\frame.py in hist(self, breaks, plot, **kwargs)
#    2514         if kwargs:
#    2515             raise H2OValueError("Unknown parameters to hist(): %r" % kwargs)
# -> 2516         hist = H2OFrame._expr(expr=ExprNode("hist", self, breaks))._frame()
#    2517
#    2518         if plot:
#
# C:\Anaconda\lib\site-packages\h2o\frame.py in _frame(self, rows, rows_offset, cols, cols_offset, fill_cache)
#     500
#     501     def _frame(self, rows=10, rows_offset=0, cols=-1, cols_offset=0, fill_cache=False):
# --> 502         self._ex._eager_frame()
#     503         if fill_cache:
#     504             self._ex._cache.fill(rows=rows, rows_offset=rows_offset, cols=cols, cols_offset=cols_offset)
#
# ...

# %%
titanic['pclass']=titanic['pclass'].asfactor()

# %%
titanic['pclass'].summary()
# Out:
# <table>
# <thead>
# <tr><th>       </th><th>pclass  </th></tr>
# </thead>
# <tbody>
# <tr><td>type   </td><td>enum    </td></tr>
# <tr><td>mins   </td><td>        </td></tr>
# <tr><td>mean   </td><td>        </td></tr>
# <tr><td>maxs   </td><td>        </td></tr>
# <tr><td>sigma  </td><td>        </td></tr>
# <tr><td>zeros  </td><td>        </td></tr>
# <tr><td>missing</td><td>0       </td></tr>
# <tr><td>0      </td><td>3       </td></tr>
# <tr><td>1      </td><td>1       </td></tr>
# <tr><td>2      </td><td>3       </td></tr>
# <tr><td>3      </td><td>1       </td></tr>
# <tr><td>4      </td><td>3       </td></tr>
# <tr><td>5      </td><td>3       </td></tr>
# <tr><td>6      </td><td>1       </td></tr>
# <tr><td>7      </td><td>3       </td></tr>
# <tr><td>8      </td><td>3       </td></tr>
# <tr><td>9      </td><td>2       </td></tr>
# </tbody>
# </table>

# %%
wine=h2o.import_file(r'C:\Users\Lenovo\Desktop\dataset\winequality-white.csv')
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
wine.head()
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  fixed acidity</th><th style="text-align: right;">  volatile acidity</th><th style="text-align: right;">  citric acid</th><th style="text-align: right;">  residual sugar</th><th style="text-align: right;">  chlorides</th><th style="text-align: right;">  free sulfur dioxide</th><th style="text-align: right;">  total sulfur dioxide</th><th style="text-align: right;">  density</th><th style="text-align: right;">  pH</th><th style="text-align: right;">  sulphates</th><th style="text-align: right;">  alcohol</th><th style="text-align: right;">  quality</th></tr>
# </thead>
# <tbody>
# ...

# %%
features=list(wine.columns)

# %%
features.remove('quality')

# %%
features
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol']

# %%
wine_split=wine.split_frame(ratios=[0.8])

# %%
wine_train=wine_split[0]                               #training set
wine_test=wine_split[1]                             #testing set

# %%
wine_train.head(4)
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  fixed acidity</th><th style="text-align: right;">  volatile acidity</th><th style="text-align: right;">  citric acid</th><th style="text-align: right;">  residual sugar</th><th style="text-align: right;">  chlorides</th><th style="text-align: right;">  free sulfur dioxide</th><th style="text-align: right;">  total sulfur dioxide</th><th style="text-align: right;">  density</th><th style="text-align: right;">  pH</th><th style="text-align: right;">  sulphates</th><th style="text-align: right;">  alcohol</th><th style="text-align: right;">  quality</th></tr>
# </thead>
# <tbody>
# ...

# %%
wine_train.shape
# Out:
# (3905, 12)

# %%
wine_train.max()
# Out:
# 344.0

# %%
len(wine)
# Out:
# 4898

# %%
copy(wine)
# Out:
# The system cannot find the file specified.

# %%
from h2o.estimators.glm import H2OGeneralizedLinearEstimator  #Libraries

# %%
glm_default=H2OGeneralizedLinearEstimator()

# %%
glm_default.train(x=features,y='quality',training_frame=wine_train)
# Out:
# glm Model Build progress: |███████████████████████████████████████████████| 100%

# %%
glm_default
# Out:
# Model Details
# ...
# H2OGeneralizedLinearEstimator :  Generalized Linear Modeling
# Model Key:  GLM_model_python_1539318570413_1
#
#
# ModelMetricsRegressionGLM: glm
# ** Reported on train data. **
#
# MSE: 0.5570417600234192
# RMSE: 0.7463523028861231
# MAE: 0.581623405713318
# RMSLE: 0.11005012151159127
# R^2: 0.28480284169143255
# Mean Residual Deviance: 0.5570417600234192
# Null degrees of freedom: 3904
# Residual degrees of freedom: 3893
# Null deviance: 3041.4663252240707
# Residual deviance: 2175.248072891452
# AIC: 8823.035600847508
# Scoring History:
#     timestamp            duration    iterations    negative_log_likelihood    objective
# --  -------------------  ----------  ------------  -------------------------  -----------
#     2018-10-12 12:00:45  0.000 sec   0             3041.47                    0.778865

# %%
glm_default.model_performance(wine_test)
# Out:
# ModelMetricsRegressionGLM: glm
# ** Reported on test data. **
#
# MSE: 0.589627507632014
# RMSE: 0.7678720646253606
# MAE: 0.5947308948429041
# RMSLE: 0.11559470172822182
# R^2: 0.26695109203931455
# Mean Residual Deviance: 0.589627507632014
# Null degrees of freedom: 992
# Residual degrees of freedom: 981
# Null deviance: 799.7280253655559
# Residual deviance: 585.5001150785899
# AIC: 2319.4454924758284

# %%
from h2o.estimators.random_forest import H2ORandomForestEstimator

# %%
drf_default=H2ORandomForestEstimator()

# %%
drf_default.train(x=features,y='quality',training_frame=wine_train)
# Out:
# drf Model Build progress: |███████████████████████████████████████████████| 100%

# %%
drf_default.train(x=features,y='quality',training_frame=wine_train)
# Out:
# drf Model Build progress: |███████████████████████████████████████████████| 100%

# %%
drf_default
# Out:
# Model Details
# ...
# H2ORandomForestEstimator :  Distributed Random Forest
# Model Key:  DRF_model_python_1539318570413_3
#
#
# ModelMetricsRegression: drf
# ** Reported on train data. **
#
# MSE: 0.38629173084122187
# RMSE: 0.6215237170383942
# MAE: 0.4459895124325544
# RMSLE: 0.09306714228234586
# Mean Residual Deviance: 0.38629173084122187
# Scoring History:
#      timestamp            duration    number_of_trees    training_rmse       training_mae         training_deviance
# ---  -------------------  ----------  -----------------  ------------------  -------------------  -------------------
#      2018-10-12 12:21:07  0.005 sec   0.0                nan                 nan                  nan
#      2018-10-12 12:21:07  0.035 sec   1.0                0.8915558284844504  0.5620603587369354   0.7948717953045947
#      2018-10-12 12:21:07  0.055 sec   2.0                0.8609289092745375  0.556273883126145    0.7411985868246447
# ...

# %%
from h2o.estimators.random_forest import H2ORandomForestEstimator

# %%
from h2o.estimators.gbm import H2OGradientBoostingEstimator

# %%
gbm_default=H2ORandomForestEstimator()

# %%
gbm_default.train(x=features,y='quality',training_frame=wine_train)
# Out:
# drf Model Build progress: |███████████████████████████████████████████████| 100%

# %%
gbm_default
# Out:
# Model Details
# ...
# H2ORandomForestEstimator :  Distributed Random Forest
# Model Key:  DRF_model_python_1539318570413_4
#
#
# ModelMetricsRegression: drf
# ** Reported on train data. **
#
# MSE: 0.38083240786399514
# RMSE: 0.6171162028856438
# MAE: 0.44506955706685825
# RMSLE: 0.09242852963192906
# Mean Residual Deviance: 0.38083240786399514
# Scoring History:
#      timestamp            duration    number_of_trees    training_rmse       training_mae         training_deviance
# ---  -------------------  ----------  -----------------  ------------------  -------------------  -------------------
#      2018-10-12 12:26:59  0.000 sec   0.0                nan                 nan                  nan
#      2018-10-12 12:26:59  0.030 sec   1.0                0.9053193667622182  0.567659963618268    0.8196031558347437
#      2018-10-12 12:26:59  0.044 sec   2.0                0.8666982436231719  0.5451911723249779   0.7511658454994911
# ...

# %%
gbm_default.model_performance(wine_test)
# Out:
# ModelMetricsRegression: drf
# ** Reported on test data. **
#
# MSE: 0.3689720251521474
# RMSE: 0.6074306751820716
# MAE: 0.43167924883862635
# RMSLE: 0.09318666604693983
# Mean Residual Deviance: 0.3689720251521474

# %%
#build a deep learning (Deep Neural Network,DNN)model
from h2o.estimators.deeplearning import H2ODeepLearningEstimator

# %%
dnn_default=H2ODeepLearningEstimator()

# %%
dnn_default.train(x=features,y='quality',training_frame=wine_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a42185de2e6a> in <module>()
# ----> 1 dnn_default.train(x=features,y='quality',training_frame=wine_train)
#
# NameError: name 'features' is not defined

# %%
features=list(wine.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-95045e9edc8f> in <module>()
# ----> 1 features=list(wine.columns)
#
# NameError: name 'wine' is not defined

# %%
from h2o.estimators.random_forest import H2ORandomForestEstimator

# %%
dnn_default=H2ODeepLearningEstimator()

# %%
wine=h2o.import_file(r'C:\Users\Lenovo\Desktop\dataset\winequality-white.csv')
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-fc04e0f2ebdb> in <module>()
# ----> 1 wine=h2o.import_file(r'C:\Users\Lenovo\Desktop\dataset\winequality-white.csv')
#
# NameError: name 'h2o' is not defined

# %%
import h2o

# %%
h2o.init(nthreads=-1)
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321..... not found.
# Attempting to start a local H2O server...
# ; Java HotSpot(TM) 64-Bit Server VM (build 25.181-b13, mixed mode)
#   Starting server from C:\Anaconda\lib\site-packages\h2o\backend\bin\h2o.jar
#   Ice root: C:\Users\Lenovo\AppData\Local\Temp\tmpx2p2og63
#   JVM stdout: C:\Users\Lenovo\AppData\Local\Temp\tmpx2p2og63\h2o_Lenovo_started_from_python.out
#   JVM stderr: C:\Users\Lenovo\AppData\Local\Temp\tmpx2p2og63\h2o_Lenovo_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321... successful.
# --------------------------  -------------------------------
# H2O cluster uptime:         06 secs
# H2O cluster timezone:       Asia/Kolkata
# H2O data parsing timezone:  UTC
# H2O cluster version:        3.20.0.9
# H2O cluster version age:    10 days
# H2O cluster name:           H2O_from_python_Lenovo_woux24
# ...

# %%
wine=h2o.import_file(r'C:\Users\Lenovo\Desktop\dataset\winequality-white.csv')
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
from h2o.estimators.random_forest import H2ORandomForestEstimator

# %%
dln_default=H2ODeepLearningEstimator()

# %%
dln_default=H2ODeepLearningEstimator()

# %%
wine=h2o.import_file(r'C:\Users\Lenovo\Desktop\dataset\winequality-white.csv')
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-2cf740f3203d> in <module>()
# ----> 1 dln_default.train(x=features,y='quality',training_frame=wine_train)
#
# NameError: name 'features' is not defined

# %%
wine_split=wine.split_frame(ratios=[0.8])

# %%
from h2o.estimators.deeplearning import H2ODeepLearningEstimator

# %%
dlm_default=H2ODeepLearningEstimator()

# %%
dlm_default.train(x=features,y='quality',training_frame=wine_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-119769c3f74d> in <module>()
# ----> 1 dlm_default.train(x=features,y='quality',training_frame=wine_train)
#
# NameError: name 'features' is not defined

# %%
titanic=h2o.import_file(r'C:\Users\Lenovo\Desktop\dataset\titanic.csv')
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
titanic.head()
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  survived</th><th style="text-align: right;">  pclass</th><th>name                                               </th><th>sex   </th><th style="text-align: right;">  age</th><th style="text-align: right;">  sibsp</th><th style="text-align: right;">  parch</th><th style="text-align: right;">  ticket</th><th style="text-align: right;">   fare</th><th>cabin  </th><th>embarked  </th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">         0</td><td style="text-align: right;">       3</td><td>Braund, Mr. Owen Harris                            </td><td>male  </td><td style="text-align: right;">   22</td><td style="text-align: right;">      1</td><td style="text-align: right;">      0</td><td style="text-align: right;">     nan</td><td style="text-align: right;"> 7.25  </td><td>       </td><td>S         </td></tr>
# ...

# %%
from h2o.estimators.random_forest import H2ORandomForestEstimator

# %%
glm_default=H2OGeneralizedLinearEstimator()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-af55bf2bcea4> in <module>()
# ----> 1 glm_default=H2OGeneralizedLinearEstimator()
#
# NameError: name 'H2OGeneralizedLinearEstimator' is not defined

# %%
import h2o

# %%
h2o.init(nthreads=-1)
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321. connected.
# --------------------------  -------------------------------
# H2O cluster uptime:         21 mins 34 secs
# H2O cluster timezone:       Asia/Kolkata
# H2O data parsing timezone:  UTC
# H2O cluster version:        3.20.0.9
# H2O cluster version age:    10 days
# H2O cluster name:           H2O_from_python_Lenovo_woux24
# H2O cluster total nodes:    1
# H2O cluster free memory:    1.745 Gb
# H2O cluster total cores:    4
# H2O cluster allowed cores:  4
# H2O cluster status:         locked, healthy
# H2O connection url:         http://localhost:54321
# H2O connection proxy:
# H2O internal security:      False
# H2O API Extensions:         Algos, AutoML, Core V3, Core V4
# Python version:             3.7.0 final
# --------------------------  -------------------------------

# %%
titanic=h2o.import_file(r'C:\Users\Lenovo\Desktop\dataset\titanic.csv')
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
titanic.head
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  survived</th><th style="text-align: right;">  pclass</th><th>name                                               </th><th>sex   </th><th style="text-align: right;">  age</th><th style="text-align: right;">  sibsp</th><th style="text-align: right;">  parch</th><th style="text-align: right;">  ticket</th><th style="text-align: right;">   fare</th><th>cabin  </th><th>embarked  </th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">         0</td><td style="text-align: right;">       3</td><td>Braund, Mr. Owen Harris                            </td><td>male  </td><td style="text-align: right;">   22</td><td style="text-align: right;">      1</td><td style="text-align: right;">      0</td><td style="text-align: right;">     nan</td><td style="text-align: right;"> 7.25  </td><td>       </td><td>S         </td></tr>
# ...

# %%
features=list(titanic.columns)

# %%
features
# Out:
# ['survived',
#  'pclass',
#  'name',
#  'sex',
#  'age',
#  'sibsp',
#  'parch',
#  'ticket',
#  'fare',
#  'cabin',
#  'embarked']

# %%
titanic_split=titanic.split_frame(ratios=[0.8])

# %%
titanic_train=titanic_split[0]                               #training set
titanic_test=titanic_split[1]                             #testing set

# %%
from h2o.estimators.glm import H2OGeneralizedLinearEstimator  #Libraries

# %%
dln_default=H2ODeepLearningEstimator()

# %%
dln_default.train(x=features,y='quality',training_frame=titanic_train)
# Out:
# ---------------------------------------------------------------------------
# H2OValueError                             Traceback (most recent call last)
# <ipython-input-61-5ab056539429> in <module>()
# ----> 1 dln_default.train(x=features,y='quality',training_frame=titanic_train)
#
# C:\Anaconda\lib\site-packages\h2o\estimators\estimator_base.py in train(self, x, y, training_frame, offset_column, fold_column, weights_column, validation_frame, max_runtime_secs, ignored_columns, model_id, verbose)
#     144             else:
#     145                 if y not in names:
# --> 146                     raise H2OValueError("Column %s does not exist in the training frame" % y)
#     147             self._estimator_type = "classifier" if training_frame.types[y] == "enum" else "regressor"
#     148         else:
#
# H2OValueError: Column quality does not exist in the training frame

# %%
titanic['pclass']=titanic['pclass'].asfactor()

# %%
# Out:
# ---------------------------------------------------------------------------
# H2OValueError                             Traceback (most recent call last)
# <ipython-input-63-5ab056539429> in <module>()
# ----> 1 dln_default.train(x=features,y='quality',training_frame=titanic_train)
#
# C:\Anaconda\lib\site-packages\h2o\estimators\estimator_base.py in train(self, x, y, training_frame, offset_column, fold_column, weights_column, validation_frame, max_runtime_secs, ignored_columns, model_id, verbose)
#     144             else:
#     145                 if y not in names:
# --> 146                     raise H2OValueError("Column %s does not exist in the training frame" % y)
#     147             self._estimator_type = "classifier" if training_frame.types[y] == "enum" else "regressor"
#     148         else:
#
# H2OValueError: Column quality does not exist in the training frame

# %%
features=list(titanic.columns)

# %%
import pandas as pd

# %%
titanic=h2o.import_file(r'C:\Users\Lenovo\Desktop\dataset\titanic.csv')
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
titanic.head
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  survived</th><th style="text-align: right;">  pclass</th><th>name                                               </th><th>sex   </th><th style="text-align: right;">  age</th><th style="text-align: right;">  sibsp</th><th style="text-align: right;">  parch</th><th style="text-align: right;">  ticket</th><th style="text-align: right;">   fare</th><th>cabin  </th><th>embarked  </th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">         0</td><td style="text-align: right;">       3</td><td>Braund, Mr. Owen Harris                            </td><td>male  </td><td style="text-align: right;">   22</td><td style="text-align: right;">      1</td><td style="text-align: right;">      0</td><td style="text-align: right;">     nan</td><td style="text-align: right;"> 7.25  </td><td>       </td><td>S         </td></tr>
# ...

# %%
features=list(titanic.columns)

# %%
features
# Out:
# ['survived',
#  'pclass',
#  'name',
#  'sex',
#  'age',
#  'sibsp',
#  'parch',
#  'ticket',
#  'fare',
#  'cabin',
#  'embarked']

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-55595c39116b> in <module>()
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 2 titanic.groupby('survived').mean().plot(kind='bar')
#
# AttributeError: 'H2OFrame' object has no attribute 'groupby'

# %%
titanic['survived'].summary()
# Out:
# <table>
# <thead>
# <tr><th>       </th><th>survived          </th></tr>
# </thead>
# <tbody>
# <tr><td>type   </td><td>int               </td></tr>
# <tr><td>mins   </td><td>0.0               </td></tr>
# <tr><td>mean   </td><td>0.3838383838383838</td></tr>
# <tr><td>maxs   </td><td>1.0               </td></tr>
# <tr><td>sigma  </td><td>0.4865924542648575</td></tr>
# <tr><td>zeros  </td><td>549               </td></tr>
# <tr><td>missing</td><td>0                 </td></tr>
# <tr><td>0      </td><td>0.0               </td></tr>
# <tr><td>1      </td><td>1.0               </td></tr>
# <tr><td>2      </td><td>1.0               </td></tr>
# <tr><td>3      </td><td>1.0               </td></tr>
# <tr><td>4      </td><td>0.0               </td></tr>
# <tr><td>5      </td><td>0.0               </td></tr>
# <tr><td>6      </td><td>0.0               </td></tr>
# <tr><td>7      </td><td>0.0               </td></tr>
# <tr><td>8      </td><td>1.0               </td></tr>
# ...

# %%
titanic['survived'].summary()
# Out:
# <table>
# <thead>
# <tr><th>       </th><th>survived          </th></tr>
# </thead>
# <tbody>
# <tr><td>type   </td><td>int               </td></tr>
# <tr><td>mins   </td><td>0.0               </td></tr>
# <tr><td>mean   </td><td>0.3838383838383838</td></tr>
# <tr><td>maxs   </td><td>1.0               </td></tr>
# <tr><td>sigma  </td><td>0.4865924542648575</td></tr>
# <tr><td>zeros  </td><td>549               </td></tr>
# <tr><td>missing</td><td>0                 </td></tr>
# <tr><td>0      </td><td>0.0               </td></tr>
# <tr><td>1      </td><td>1.0               </td></tr>
# <tr><td>2      </td><td>1.0               </td></tr>
# <tr><td>3      </td><td>1.0               </td></tr>
# <tr><td>4      </td><td>0.0               </td></tr>
# <tr><td>5      </td><td>0.0               </td></tr>
# <tr><td>6      </td><td>0.0               </td></tr>
# <tr><td>7      </td><td>0.0               </td></tr>
# <tr><td>8      </td><td>1.0               </td></tr>
# ...

# %%
titanic[titanic['sex']=='male'].fare.hist()

# %%
titanic[titanic['sex']=='female'].fare.hist()

# %%
titanic=pd.read_csv(r'C:\Users\Lenovo\Desktop\dataset\titanic.csv')

# %%
titanic[titanic['survived']==1].loc[titanic['sex']=='male'].count()
# Out:
# survived    109
# pclass      109
# name        109
# sex         109
# age          93
# sibsp       109
# parch       109
# ticket      109
# fare        109
# cabin        45
# embarked    109
# dtype: int64

# %%
titanic[titanic['survived']==1].loc[titanic['sex']=='female'].count()
# Out:
# survived    233
# pclass      233
# name        233
# sex         233
# age         197
# sibsp       233
# parch       233
# ticket      233
# fare        233
# cabin        91
# embarked    231
# dtype: int64

# %%
import pandas as pd

# %%
s=pd.read_csv('http://www-bcf.usc.edu/~gareth/ISL/Advertising.csv')

# %%
s.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
s.tail()
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
s
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# 5             6    8.7   48.9       75.0    7.2
# 6             7   57.5   32.8       23.5   11.8
# 7             8  120.2   19.6       11.6   13.2
# 8             9    8.6    2.1        1.0    4.8
# 9            10  199.8    2.6       21.2   10.6
# 10           11   66.1    5.8       24.2    8.6
# 11           12  214.7   24.0        4.0   17.4
# 12           13   23.8   35.1       65.9    9.2
# 13           14   97.5    7.6        7.2    9.7
# 14           15  204.1   32.9       46.0   19.0
# 15           16  195.4   47.7       52.9   22.4
# 16           17   67.8   36.6      114.0   12.5
# 17           18  281.4   39.6       55.8   24.4
# 18           19   69.2   20.5       18.3   11.3
# ...

# %%
s
